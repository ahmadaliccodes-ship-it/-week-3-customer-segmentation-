# %% [markdown]
# # Phase 1 — Project Setup & Dataset Understanding
#
# **Project:** Wholesale Customer Segmentation
#
# Phase 1 - Project Setup & Objective
# Wholesale Customers Clustering Analysis
#
# Steps covered (per implementation plan):
#  1. Define the project objective
#  2. Load the dataset
#  3. Preserve the raw data
#  4. Understand the dataset (shape, dtypes, describe, head)

# %% [markdown]
# ## Objective
# Load and understand the Wholesale Customers dataset, define the business problem, and establish the data used for clustering.
#
# ## Method
# Load the raw UCI dataset, preserve the source data, inspect dimensions, schema, categorical context, and the six annual spending variables.
#
# ## Results
# The dataset contains 440 customers and eight variables. Six annual spending variables are the clustering inputs; Channel and Region are contextual variables.
#
# ## Interpretation
# The data is suitable for an unsupervised customer-segmentation workflow because the spending variables provide customer-level behavioral information while Channel and Region can be retained for post-hoc interpretation.
#
# ## Conclusion
# The project has a defined business objective, documented inputs, and a reproducible starting point for downstream analysis.

# %% [markdown]
# ### How to use this notebook
# Run cells from top to bottom. Keep the project files in the same folder as this notebook. Phases 1–4 create the data preparation artifacts used by later phases; Phases 5–9 read those artifacts; Phase 10 assembles the final report.

# %%
from pathlib import Path
import os
import sys

# Resolve the project root so notebooks can import the canonical src modules.
PROJECT_ROOT = Path.cwd()
while PROJECT_ROOT != PROJECT_ROOT.parent and not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
os.chdir(PROJECT_ROOT)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print(f"Project root: {PROJECT_ROOT}")
# Out:
# Project root: <project-root>

# %%
from src.preprocessing import PROJECT_OBJECTIVE, DATA_DICTIONARY, load_raw_data, profile_dataset
df_raw = load_raw_data(snapshot=True)

# %% [markdown]
# ### Phase 1 checkpoint
#
# Review the outputs and figures generated by this phase before moving to the next phase.
